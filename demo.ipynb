# %%
import numpy as np
import matplotlib.pyplot as plt
import soundfile as sf
from IPython.display import Audio
import librosa
import source as s

# %%
# file = sf.read('goodjob.wav') # test file 1
file = sf.read(librosa.ex('trumpet')) # alternative test file 2
sr = file[1]
echo_file = s.echo_mod(file = file, delay_time = .5, amp_rate = 1.08, speedup_rate=1.09, ratio = .5)
Audio(data=echo_file, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
